# %% [markdown]
# <a href="https://colab.research.google.com/github/akemisetti/ucsfimaging/blob/master/SelectingImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlretrieve
urlretrieve("http://therestlessengineer.com/compressed_sensing.tar.gz","compressed_sensing.tar.gz")
# Out:
# ('compressed_sensing.tar.gz', <http.client.HTTPMessage at 0x7f8a365c62b0>)

# %%
# !tar -xvf compressed_sensing.tar.gz
# Out:
# compressed_sensing/
# compressed_sensing/file1000019.h5
# compressed_sensing/loupe/
# compressed_sensing/loupe/__pycache__/
# compressed_sensing/loupe/__pycache__/__init__.cpython-37.pyc
# compressed_sensing/loupe/__pycache__/__init__.cpython-36.pyc
# compressed_sensing/loupe/__pycache__/layers.cpython-37.pyc
# compressed_sensing/loupe/__pycache__/models.cpython-37.pyc
# compressed_sensing/loupe/__pycache__/layers.cpython-36.pyc
# compressed_sensing/loupe/__pycache__/models.cpython-36.pyc
# compressed_sensing/loupe/models.py
# compressed_sensing/loupe/__init__.py
# compressed_sensing/loupe/.ipynb_checkpoints/
# compressed_sensing/loupe/.ipynb_checkpoints/layers-checkpoint.py
# compressed_sensing/loupe/layers.py
# compressed_sensing/InferenceDemo.ipynb
# compressed_sensing/.ipynb_checkpoints/
# compressed_sensing/.ipynb_checkpoints/InferenceDemo-checkpoint.ipynb
# compressed_sensing/data_2/
# compressed_sensing/data_2/singlecoil_train/
# ...

# %%
! ls /content
# Out:
# compressed_sensing  compressed_sensing.tar.gz  sample_data

# %%
import sys
sys.path.append('/content/compressed_sensing')

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
import loupe
import keras
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider
import ipywidgets as widgets
import matplotlib.cm
from keras.utils import plot_model

# %%
file_number = '4' #@param {type:"string"}
plt.rcParams['image.cmap'] = 'gray'
f = np.stack(np.load('/content/compressed_sensing/data_2/singlecoil_train/data-'+file_number+'.npy'))[..., np.newaxis]
f.shape
# Out:
# (42, 320, 320, 1)

# %%
_, axs = plt.subplots(7, 7, figsize=(30, 24))
axs = axs.flatten()

for x, ax in zip(list(range(0,f.shape[0])), axs):
    ax.imshow(f[x,:,:,0])
    ax.set_xlabel("Fig. "+str(x))
plt.show()

# %%
range_to_save = [int(file_number),0,9]
with open('/content/compressed_sensing/data_out/outputfile.csv', 'a') as f:
    _ = str(range_to_save).replace('[','').replace(']','')
    f.write(_+'\n')
